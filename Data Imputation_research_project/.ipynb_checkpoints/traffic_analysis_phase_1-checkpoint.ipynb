# %% [markdown]
# ## Bi-DW-KNN : Data Imputation for Univariate Time Series

# %% [markdown]
# ### Loading numpy,pandas sklearn and matplotlib libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
from sklearn.impute import KNNImputer
from sklearn.impute import SimpleImputer
import array
import statistics
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from math import sqrt

# %% [markdown]
# ### creating Data Frame by loading Traffic sensor data from California
#
# This data set has below columns
# - Timestamp
# - Vehicle Hours
# - Vehicle Miles
# - Lane Points

# %%
df = pd.read_csv('data\pems_output.csv',header=0)
print(df.head)
# Out:
# <bound method NDFrame.head of                   Hour       VHT         VMT   Lane_Points  Observed
# 0        3/1/2020 0:00  104762.9   7015629.8      421212.0      65.2
# 1        3/1/2020 1:00   72617.5   4851091.0      421212.0      65.2
# 2        3/1/2020 2:00   58848.7   3920233.0      421212.0      65.2
# 3        3/1/2020 3:00   47502.0   3157263.3      420162.0      65.2
# 4        3/1/2020 4:00   49846.5   3310866.3      421356.0      65.2
# ...                ...       ...         ...           ...       ...
# 17838   3/14/2022 9:00  360370.0  20859266.4      433109.0      56.4
# 17839  3/14/2022 10:00  347459.2  20559468.4      433107.0      56.4
# 17840  3/14/2022 11:00  352971.4  20977783.1      433088.0      56.4
# 17841  3/14/2022 12:00  365768.4  21746139.2      433094.0      56.4
# 17842  3/14/2022 13:00  381860.3  22585788.6      433126.0      56.4
#
# [17843 rows x 5 columns]>

# %% [markdown]
# *note : Considering the capacity of my machine, we considered 500 observations of the dataset.*

# %%
df = df[:500]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Hour          500 non-null    object
#  1   VHT           500 non-null    float64
#  2   VMT           500 non-null    float64
#  3    Lane_Points  500 non-null    float64
#  4   Observed      500 non-null    float64
# dtypes: float64(4), object(1)
# memory usage: 19.7+ KB

# %%
#print(df['Hour'])
#print(df['VHT'])
#plt.plot(df['Hour'],df['VHT'],color='red',marker='o',markerfacecolor='blue')
#plt.xlabel("Time")
#plt.ylabel("VHT (Veh-Hours)")

# %% [markdown]
# **Trying to understand the nature of the data by ploting sensor data against timestamp**
# <br>
# **Here X-axis is timestamp and Y-axis is Vechicle Hours collected from California Traffic sensor**

# %%
df_graph = df[:100]
plt.figure(figsize=(18, 8))
plt.plot(df_graph.Hour, df_graph['VHT'])
plt.xlabel("Hour", fontsize=14)
plt.ylabel("VHT (Veh-Hours)", fontsize=14)
plt.xticks(np.arange(0, len(df_graph.Hour)+1, 1), rotation=90, fontsize=12)
plt.yticks(fontsize=14)
plt.title("Recorded Vehcle Hours", fontsize=16)
plt.show()

# %% [markdown]
# #### Defining the parameters before applying KNN alorithms
# - Window size is defined in window variable
# - neighbor of KNN algorithm is defined in knn_neighbors variable

# %%
window = 48
window_start_index = 0
knn_neighbors = 15
N = len(df)
#print('Data Length:',N)

a_list = list(range(1, N+1))
#print(a_list)

# %% [markdown]
# #### Nullifying some of the data elements, so that we can compute the values using below algorithms.
# - Bi-SW-KNN
# - KNN
# - Simple Imputer

# %%
Before_imputation = df
missing_val_locations = [226,250,274,298,322,346,370,394,397]
missing_val = []

for x in missing_val_locations:
    #print('Try to impute this value:',Before_imputation.iloc[x,1])
    missing_val.append(Before_imputation.iloc[x,1])
    Before_imputation.iloc[x,1] = np.nan;
Before_imputation.Hour=a_list

#print(Before_imputation)

# %% [markdown]
# ### Below is the Algorithm of our proposed method Bi-SW-KNN
# ![Capture.PNG](attachment:Capture.PNG)

# %%
imputer = KNNImputer(n_neighbors=knn_neighbors)
counter = 0
biSWknn_imputed_vals = []
for missing_val_loc in missing_val_locations:
    print('missing_val_loc', missing_val_loc)
    print('Try to impute this value:',missing_val[counter])
    list_imputed_vals = []
    for i in range(0, window):
        start_index = missing_val_loc - (window - 1)+i
        end_index = start_index + window
        missing_val_index = end_index-(start_index+1+i)
        #print('start index', start_index)
        #print('end index', end_index)
        working_data = Before_imputation[start_index : end_index]
        #print('working_data',working_data)
        #print('Try to impute this value:',working_data.iloc[missing_val_loc-i,1])
        After_imputation = imputer.fit_transform(working_data)
        # print dataset after performing the operation
        #print("\n\nAfter performing imputation\n",After_imputation)
        #print("\n1------------",missing_val_loc-i)
        #print("\n2------------",missing_val_index)
        #print('Try to impute this value:',After_imputation[missing_val_loc-i,1])
        #print('After impute this value:',After_imputation[missing_val_index,1])
        list_imputed_vals.append(After_imputation[missing_val_index,1])
    counter = counter + 1;
    #print('list of possible values',list_imputed_vals)  
    print('Mean of data-set is : ',statistics.mean(list_imputed_vals))
    biSWknn_imputed_vals.append(statistics.mean(list_imputed_vals))
    #print('Median of data-set is : ',statistics.median(list_imputed_vals))
# Out:
# missing_val_loc 226
# Try to impute this value: 332696.2
# Mean of data-set is :  359666.8688888889
# missing_val_loc 250
# Try to impute this value: 340207.2
# Mean of data-set is :  371631.222638889
# missing_val_loc 274
# Try to impute this value: 361926.8
# Mean of data-set is :  368915.8329166667
# missing_val_loc 298
# Try to impute this value: 367195.1
# Mean of data-set is :  376648.42250000004
# missing_val_loc 322
# Try to impute this value: 329703.4
# Mean of data-set is :  329681.9701388889
# missing_val_loc 346
# Try to impute this value: 277620.4
# Mean of data-set is :  289502.87861111114
# missing_val_loc 370
# Try to impute this value: 306692.9
# Mean of data-set is :  301854.61624999996
# missing_val_loc 394
# Try to impute this value: 285007.6
# Mean of data-set is :  289128.39194444445
# missing_val_loc 397
# Try to impute this value: 333507.7
# Mean of data-set is :  327298.55333333334

# %% [markdown]
# ### Regression accuracy metrics
#
#    The MSE, MAE, RMSE, and R-Squared are mainly used metrics to evaluate the prediction error rates and model performance in regression analysis.
#
# - MAE (Mean absolute error) represents the difference between the original and predicted values extracted by averaged the absolute difference over the data set.
# - MSE (Mean Squared Error) represents the difference between the original and predicted values extracted by squared the average difference over the data set.
# - RMSE (Root Mean Squared Error) is the error rate by the square root of MSE.
# - R-squared (Coefficient of determination) represents the coefficient of how well the values fit compared to the original values. The value from 0 to 1 interpreted as percentages. The higher the value is, the better the model is.

# %%
print('Actual values:',missing_val)
print('Predicted values:',biSWknn_imputed_vals)

r2 = r2_score(missing_val,biSWknn_imputed_vals)
print('R2 score of sliding window bi-direction KNN:',r2)

rmse = mean_squared_error(missing_val, biSWknn_imputed_vals, squared=False)
print('RMSE score of sliding window bi-direction KNN:',rmse)

mae = mean_absolute_error(missing_val, biSWknn_imputed_vals)
print('MAE score of sliding window bi-direction KNN:',mae)
# Out:
# Actual values: [332696.2, 340207.2, 361926.8, 367195.1, 329703.4, 277620.4, 306692.9, 285007.6, 333507.7]
# Predicted values: [359666.8688888889, 371631.222638889, 368915.8329166667, 376648.42250000004, 329681.9701388889, 289502.87861111114, 301854.61624999996, 289128.39194444445, 327298.55333333334]
# R2 score of sliding window bi-direction KNN: 0.7306866835532864
# RMSE score of sliding window bi-direction KNN: 15177.597679651619
# MAE score of sliding window bi-direction KNN: 11323.241975308674

# %%
imputer = KNNImputer(n_neighbors=knn_neighbors)
knn_imputed_vals = []
After_imputation = imputer.fit_transform(Before_imputation)
 # print dataset after performing the operation
for missing_val_loc in missing_val_locations:
    print("After performing imputation\n",After_imputation[missing_val_loc,1])
    knn_imputed_vals.append(After_imputation[missing_val_loc,1])
# Out:
# After performing imputation
#  332289.39333333337
# After performing imputation
#  346791.0866666666
# After performing imputation
#  349994.1733333333
# After performing imputation
#  373648.5933333334
# After performing imputation
#  345480.66000000003
# After performing imputation
#  286419.2866666667
# After performing imputation
#  302176.17999999993
# After performing imputation
#  281233.6533333333
# After performing imputation
#  349994.1733333333

# %%
print('Actual values:',missing_val)
print('Predicted values:',knn_imputed_vals)

r2 = r2_score(missing_val,knn_imputed_vals)
print('R2 score of KNNImputer:',r2)

rmse = mean_squared_error(missing_val, knn_imputed_vals, squared=False)
print('RMSE score of KNNImputer:',rmse)

mae = mean_absolute_error(missing_val, knn_imputed_vals)
print('MAE score of KNNImputer:',mae)
# Out:
# Actual values: [332696.2, 340207.2, 361926.8, 367195.1, 329703.4, 277620.4, 306692.9, 285007.6, 333507.7]
# Predicted values: [332289.39333333337, 346791.0866666666, 349994.1733333333, 373648.5933333334, 345480.66000000003, 286419.2866666667, 302176.17999999993, 281233.6533333333, 349994.1733333333]
# R2 score of KNNImputer: 0.8882420972719868
# RMSE score of KNNImputer: 9777.171746956601
# MAE score of KNNImputer: 8303.344444444449

# %%
sim_imputer = SimpleImputer(missing_values=np.nan, strategy='mean')
sim_imputed_vals = []
After_sim_imputation = sim_imputer.fit_transform(Before_imputation)
 # print dataset after performing the operation
for missing_val_loc in missing_val_locations:
    print("After performing imputation\n",After_sim_imputation[missing_val_loc,1])
    sim_imputed_vals.append(After_sim_imputation[missing_val_loc,1])
# Out:
# After performing imputation
#  252436.12240325863
# After performing imputation
#  252436.12240325863
# After performing imputation
#  252436.12240325863
# After performing imputation
#  252436.12240325863
# After performing imputation
#  252436.12240325863
# After performing imputation
#  252436.12240325863
# After performing imputation
#  252436.12240325863
# After performing imputation
#  252436.12240325863
# After performing imputation
#  252436.12240325863

# %%
print('Actual values:',missing_val)
print('Predicted values:',sim_imputed_vals)

r2 = r2_score(missing_val,sim_imputed_vals)
print('R2 score of SimpleImputer:',r2)

rmse = mean_squared_error(missing_val, sim_imputed_vals, squared=False)
print('RMSE score of SimpleImputer:',rmse)

mae = mean_absolute_error(missing_val, sim_imputed_vals)
print('MAE score of SimpleImputer:',mae)
# Out:
# Actual values: [332696.2, 340207.2, 361926.8, 367195.1, 329703.4, 277620.4, 306692.9, 285007.6, 333507.7]
# Predicted values: [252436.12240325863, 252436.12240325863, 252436.12240325863, 252436.12240325863, 252436.12240325863, 252436.12240325863, 252436.12240325863, 252436.12240325863, 252436.12240325863]
# R2 score of SimpleImputer: -6.3374100213325635
# RMSE score of SimpleImputer: 79221.94794464365
# MAE score of SimpleImputer: 73625.7998189636

# %% [markdown]
# ![Matrix.PNG](attachment:Matrix.PNG)
